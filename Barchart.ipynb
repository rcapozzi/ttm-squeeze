# %%
# https://www.barchart.com/etfs-funds/quotes/QQQ/cheat-sheet
import json
import requests
from urllib.parse import unquote
import requests_cache
session = requests_cache.CachedSession('yfinance.cache')
session.headers['User-agent'] = 'my-program/1.0'
headers = {
    "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:86.0) Gecko/20100101 Firefox/86.0"
}
session.headers['User-agent'] = "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:86.0) Gecko/20100101 Firefox/86.0"

# %%
data = None

# %%
url = "https://www.barchart.com/proxies/core-api/v1/quotes/get?list=options.mostActive.us&fields=symbol,symbolName,lastPrice,priceChange,percentChange,optionsTotalVolume,optionsWeightedImpliedVolatility,optionsImpliedVolatilityRank1y,optionsImpliedVolatilityPercentile1y,optionsWeightedImpliedVolatilityHigh1y,tradeTime,symbolCode,symbolType,hasOptions&between(lastPrice,.10,)=&between(tradeTime,2021-03-22,2021-03-23)=&orderBy=optionsTotalVolume&orderDir=desc&meta=field.shortName,field.type,field.description&hasOptions=true&page=1&limit=100&raw=1"

if not data:
    with requests.Session() as s:
        # get all cookies
        s.get(
            "https://www.barchart.com/options/iv-rank-percentile/stocks",
            headers=headers,
        )
        # use one cookie as HTTP header
        headers["X-XSRF-TOKEN"] = unquote(s.cookies["XSRF-TOKEN"])
        data = s.get(url, headers=headers).json()


# uncomment this to print all data:
#print(json.dumps(data, indent=4))

for d in data["data"]:
    print("{:<8}{:<50}{}".format(d["symbol"], d["symbolName"], d["optionsImpliedVolatilityRank1y"]))
# Out:
# AMD     Adv Micro Devices                                 27.84%
# AAPL    Apple Inc                                         4.35%
# TSLA    Tesla Inc                                         4.17%
# AMZN    Amazon.com Inc                                    17.87%
# AMC     AMC Entertainment Holdings Inc                    15.96%
# PINS    Pinterest Inc                                     12.64%
# NIO     Nio Inc ADR                                       14.01%
# BAC     Bank of America Corp                              10.10%
# BABA    Alibaba Group Holding ADR                         49.54%
# FB      Facebook Inc                                      9.16%
# F       Ford Motor Company                                4.75%
# BA      Boeing Company                                    4.04%
# AAL     American Airlines Gp                              10.18%
# NVDA    Nvidia Corp                                       20.45%
# ATOS    Atossa Therapeutics Inc                           9.94%
# PFE     Pfizer Inc                                        2.20%
# PLTR    Palantir Technologies Inc Cl A                    6.93%
# GE      General Electric Company                          10.28%
# SNAP    Snap Inc                                          2.85%
# MSFT    Microsoft Corp                                    2.34%
# CLF     Cleveland-Cliffs Inc                              13.97%
# CCL     Carnival Corp                                     22.93%
# TLRY    Tilray Inc                                        6.76%
# ROKU    Roku Inc                                          47.26%
# PYPL    Paypal Holdings                                   9.32%
# M       Macy's Inc                                        18.21%
# VALE    Vale S.A. ADR                                     28.29%
# X       United States Steel Corp                          0.00%
# GM      General Motors Company                            23.64%
# MRNA    Moderna Inc                                       19.18%
# BB      Blackberry Ltd                                    7.86%
# T       AT&T Inc                                          8.56%
# DAL     Delta Air Lines Inc                               16.98%
# SPCE    Virgin Galactic Holdings Inc                      10.58%
# SAVA    Cassava Sciences Inc                              23.44%
# UBER    Uber Technologies Inc                             33.34%
# XOM     Exxon Mobil Corp                                  15.56%
# UAL     United Airlines Holdings Inc                      10.63%
# GME     Gamestop Corp                                     1.96%
# DIS     Walt Disney Company                               27.97%
# LI      Li Auto Inc ADR                                   14.71%
# MGM     MGM Resorts International                         33.66%
# ABNB    Airbnb Inc Cl A                                   8.99%
# RIOT    Riot Blockchain Inc                               6.47%
# NOK     Nokia Corp ADR                                    1.82%
# C       Citigroup Inc                                     8.51%
# GPS     Gap Inc                                           21.61%
# SQ      Square                                            23.91%
# CLOV    Clover Health Investments Corp                    15.35%
# MARA    Marathon Digital Hldgs Inc                        4.47%
# WFC     Wells Fargo & Company                             9.23%
# PLUG    Plug Power Inc                                    5.69%
# PBR     Petroleo Brasileiro S.A. Petrobras ADR            18.85%
# INTC    Intel Corp                                        5.92%
# RCL     Royal Caribbean Cruises Ltd                       28.61%
# JPM     JP Morgan Chase & Company                         4.55%
# TWTR    Twitter Inc                                       4.59%
# NCLH    Norwegian Cruise Ord                              23.56%
# PTON    Peloton Interactive Inc                           10.94%
# SOFI    Sofi Technologies Inc                             13.17%
# NKLA    Nikola Corp                                       18.33%
# QCOM    Qualcomm Inc                                      8.22%
# LVS     Las Vegas Sands                                   28.01%
# JD      Jd.com Inc ADR                                    39.96%
# WISH    Contextlogic Inc Cl A                             6.65%
# MU      Micron Technology                                 7.13%
# EDU     New Oriental Education & Technology Group ADR     69.88%
# SNDL    Sundial Growers Inc                               2.15%
# SBUX    Starbucks Corp                                    9.55%
# GOOGL   Alphabet Cl A                                     0.38%
# NFLX    Netflix Inc                                       2.35%
# FCX     Freeport-Mcmoran Inc                              3.40%
# ZM      Zoom Video Communications Cl A                    14.42%
# SWKS    Skyworks Solutions                                10.58%
# AMAT    Applied Materials                                 39.19%
# TEAM    Atlassian Cls A Ord                               28.29%
# BIDU    Baidu Inc ADR                                     27.10%
# ATVI    Activision Blizzard                               37.76%
# CAT     Caterpillar Inc                                   13.20%
# XPEV    Xpeng Inc ADR                                     15.41%
# PG      Procter & Gamble Company                          6.69%
# CVX     Chevron Corp                                      0.46%
# AEO     American Eagle Outfitters                         6.76%
# EBAY    Ebay Inc                                          57.15%
# RKT     Rocket Companies Inc Cl A                         7.70%
# APT     Alpha Pro Tech                                    30.03%
# GOLD    Barrick Gold Corp                                 20.99%
# DKNG    Draftkings Inc                                    14.52%
# VIAC    Viacom CBS Cl B                                   15.29%
# JMIA    Jumia Technologies Ag ADR                         17.02%
# COST    Costco Wholesale                                  4.21%
# OXY     Occidental Petroleum Corp                         20.06%
# TAL     Tal Education Group ADR                           75.26%
# CZR     Caesars Entertainment Inc                         48.33%
# SNOW    Snowflake Inc Cl A                                19.88%
# QS      Quantumscape Corp                                 0.13%
# COIN    Coinbase Global Inc Cl A                          51.23%
# CPRI    Capri Holdings Ltd                                4.32%
# LUV     Southwest Airlines Company                        14.28%
# JWN     Nordstrom                                         29.41%

# %%
detail = None
url = 'https://www.barchart.com/stocks/quotes/CROX/overview'
with requests.Session() as s:
    # get all cookies
    s.get(url, headers=headers)
    # use one cookie as HTTP header
    headers["X-XSRF-TOKEN"] = unquote(s.cookies["XSRF-TOKEN"])
    detail = s.get(url, headers=headers).json()
detail
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-7-b502e83b4395> in <module>
#       9     # use one cookie as HTTP header
#      10     headers["X-XSRF-TOKEN"] = unquote(s.cookies["XSRF-TOKEN"])
# ---> 11     detail = s.get(url, headers=headers).json()
#      12 detail
#
# /usr/lib/python3/dist-packages/requests/models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# /usr/lib/python3/dist-packages/simplejson/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, **kw)
#     516             parse_constant is None and object_pairs_hook is None
#     517             and not use_decimal and not kw):
# --> 518         return _default_decoder.decode(s)
#     519     if cls is None:
#     520         cls = JSONDecoder
#
# /usr/lib/python3/dist-packages/simplejson/decoder.py in decode(self, s, _w, _PY3)
#     368         if _PY3 and isinstance(s, bytes):
#     369             s = str(s, self.encoding)
# --> 370         obj, end = self.raw_decode(s)
#     371         end = _w(s, end).end()
#     372         if end != len(s):
#
# /usr/lib/python3/dist-packages/simplejson/decoder.py in raw_decode(self, s, idx, _w, _PY3)
#     398             elif ord0 == 0xef and s[idx:idx + 3] == '\xef\xbb\xbf':
#     399                 idx += 3
# --> 400         return self.scan_once(s, idx=_w(s, idx).end())
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
